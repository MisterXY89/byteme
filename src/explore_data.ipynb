# %%
from recommend import Recommender
import matplotlib.pyplot as plt
import numpy as np
import bayespy.plot as bpplt
import pandas as pd

# %%
model = Recommender(sim=True)
result = model.fit(cluster_size=5)

# %%
model.explainProbabilities(23)

# %%
model.plotProbabilites()

# %%
model.plotEffort()

# %%
model.recommend(kind="motivation", group_size=5)
# Out:
# {'Group 1': array([ 0,  3, 11, 19, 20, 21]),
#  'Group 2': array([ 1,  5,  8, 14, 15, 17]),
#  'Group 3': array([ 2,  9, 16, 18, 22, 28]),
#  'Group 4': array([ 4,  7, 12, 24, 27, 29]),
#  'Group 5': array([ 6, 10, 13, 23, 25, 26])}

# %%
model.recommend(kind="random", group_size=5)
# Out:
# {'group 0': array([11, 28,  8,  7, 14]),
#  'group 1': array([24, 25, 29,  1,  3]),
#  'group 2': array([26,  4, 20, 17, 27]),
#  'group 3': array([18,  5, 21,  9, 23]),
#  'group 4': array([15,  2, 22, 19, 12]),
#  'group 5': array([13,  6, 16,  0, 10])}
